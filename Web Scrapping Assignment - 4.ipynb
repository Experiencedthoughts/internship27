# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.

# %% [markdown]
# Importing Required Libraries

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings 
warnings.filterwarnings('ignore')
import time
# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %% [markdown]
# Connecting Webdriver

# %%
driver=webdriver.Chrome('chromedriver.exe')
time.sleep(3)

# %% [markdown]
# Opening up the Bcci url

# %%
driver.get('https://www.bcci.tv/')
time.sleep(3)

# %%
international_tags=driver.find_element_by_xpath('/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
international_tags.click()
time.sleep(3)

# %% [markdown]
# Creating the empty list to store the informations

# %%
title_list=[]
series_list=[]
place_list=[]
date_list=[]
time_list=[]

# %%
title_tags=driver.find_elements_by_xpath("//span[@class='matchOrderText ng-binding ng-scope']")
title_tags[0:8]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="4816a54a-e38d-4ef7-9e87-e278c5bbffcb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="b7d1d332-9ddc-4f9e-986c-fa22181a1c6f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="8418f4b1-7121-4c6d-ad8b-3109ad5b4418")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="1219add7-ebfb-4334-878d-ad3a801faa38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="e30b2e51-9a40-4542-a5ac-a196cccc7bde")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="cf58ccfc-a5b5-4d63-9f84-f14eee1986ba")>,
# ...

# %%
for i in title_tags:
    title=i.text
    title_list.append(title)
title_list[0:8]
# Out:
# ['1st T20I -',
#  '2nd T20I -',
#  '1st T20I -',
#  '3rd T20I -',
#  '2nd T20I -',
#  '1st ODI -',
#  '5th Test -',
#  '2nd ODI -']

# %%
time.sleep(5)

# %%
series_tags=driver.find_elements_by_xpath("//span[@class='ng-binding']")
series_tags[0:8]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="b19af806-128b-4c7e-8f11-7f1568ea3e57")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="fd9c9659-4a6d-49bc-bb05-43d321589f3c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="bddda7a9-ba0c-4e2a-8c31-cb9541d72e33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="e3d60496-2b94-40c2-9841-69e5dd2c36dd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="fe63d319-92d9-430b-8efb-cc953b226c83")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="a5b46aa8-7826-46a1-a0ca-c727c88ad057")>,
# ...

# %%
for i in series_tags:
    series=i.text
    series_list.append(series)
series_list[0:8]
# Out:
# ['INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022']

# %%
date_tags=driver.find_elements_by_xpath("//h5[@class='ng-binding']")
date_tags[0:8]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="93be0751-8601-4b89-aca1-1d9fdc68ef7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="4ada1620-a736-48df-b3b9-58bc4a7fdc30")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="67b3010f-f1ed-45ae-ad73-edc80f053bf8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="6b75b872-ef90-4415-86b7-4cf3e1e0f14c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="baf8f082-f351-4bcf-86f2-38b8f69fa43d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="7b539d06-41b3-43b1-b58c-2869c0aaa8a2")>,
# ...

# %%
for i in date_tags:
    date=i.text
    date_list.append(date)
date_list[0:8]
# Out:
# ['23 JUN 2022',
#  '25 JUN 2022',
#  '26 JUN 2022',
#  '27 JUN 2022',
#  '28 JUN 2022',
#  '1 JUL 2022',
#  '1 JUL 2022',
#  '4 JUL 2022']

# %%
time_tags=driver.find_elements_by_xpath("//h5[@class='text-right ng-binding']")
time_tags[0:8]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="b36e229c-f0d7-4f84-86a1-5348aa24a2dd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="da54c949-333a-4d83-b4ed-7a3df1cae380")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="d63b2107-9655-4d00-aad0-5992343e2412")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="742bbae1-c9c1-46b0-bf15-d230a5f678cf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="9e05a9b3-8e6a-437f-a4a0-783a546bba03")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="70380d92-6c3f-4a45-b94a-c1aa72909f48")>,
# ...

# %%
for i in time_tags:
    time=i.text
    time_list.append(time)
time_list[0:8]
# Out:
# ['2:00 PM IST',
#  '2:00 PM IST',
#  '9:00 PM IST',
#  '2:00 PM IST',
#  '9:00 PM IST',
#  '10:00 AM IST',
#  '3:30 PM IST',
#  '10:00 AM IST']

# %%
place_tags=driver.find_elements_by_xpath("//span[@class='ng-binding ng-scope']")
place_tags[0:8]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="c56fb5b2-c322-414d-a8c2-485fdc399f01")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="ad6b3df8-4d75-495c-8120-b3f219c6e707")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="46681361-2375-430c-928c-c081e6f10f08")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="cdf2037b-e330-4750-a7b5-3811185658bf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="202f1448-4984-4f68-9485-fb0f408a2045")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2d97565bafb2bd1b658fd582bc8d1a6f", element="9cb0ffb4-26a0-4f2e-865c-4c866037c64b")>,
# ...

# %%
for i in place_tags:
    place=i.text
    place_list.append(place)
place_list[0:8]
# Out:
# ['Rangiri Dambulla International Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Pallekele International Cricket Stadium,',
#  'Edgbaston,',
#  'Pallekele International Cricket Stadium,']

# %%
df=pd.DataFrame({})
df['Date']=date_list[0:8]
df['Series']=series_list[0:8]
df['Title']=title_list[0:8]
df['Place']=place_list[0:8]
df['Time']=time_list[0:8]

# %%
df
# Out:
#           Date                                         Series       Title  \
# 0  23 JUN 2022  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  1st T20I -
# 1  25 JUN 2022  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  2nd T20I -
# 2  26 JUN 2022          INDIA TOUR OF IRELAND T20 SERIES 2022  1st T20I -
# 3  27 JUN 2022  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  3rd T20I -
# 4  28 JUN 2022          INDIA TOUR OF IRELAND T20 SERIES 2022  2nd T20I -
# 5   1 JUL 2022  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022   1st ODI -
# 6   1 JUL 2022         INDIA TOUR OF ENGLAND TEST SERIES 2021  5th Test -
# 7   4 JUL 2022  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022   2nd ODI -
#
#                                       Place          Time
# 0   Rangiri Dambulla International Stadium,   2:00 PM IST
# 1   Rangiri Dambulla International Stadium,   2:00 PM IST
# 2                              The Village,   9:00 PM IST
# 3   Rangiri Dambulla International Stadium,   2:00 PM IST
# ...

# %%
driver.close()

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %% [markdown]
# Opening up the url

# %%
driver.get('https://github.com/')

# %%
import time

# %%
time.sleep(3)

# %%
exp_opt=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary")
exp_opt.click()

# %%
trend_opt=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
trend_opt.click()

# %%
dep_title_list=[]
dep_descrp_list=[]
cont_list=[]
lan_list=[]

# %%
title_tags=driver.find_elements_by_xpath("//span[@class='text-normal']")
title_tags[0:24]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="ef0b4237-6a3b-4886-960d-9ade81867e78")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="79738481-6488-489c-9c38-8038e4e54d73")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="c4ce9123-73d9-4aa9-b404-788abfd37188")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="1eb0cde4-2467-44f6-a22b-c5216a8d8e44")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="9a59967b-ef65-4ba1-8427-89c274c4220e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="84b11cdd-0167-47de-a1a2-634667ab4073")>,
# ...

# %%
for i in title_tags:
    title=i.text
    dep_title_list.append(title)
dep_title_list
# Out:
# ['mingrammer /',
#  'hashicorp /',
#  'facebook /',
#  'girliemac /',
#  'WenchaoD /',
#  'PrefectHQ /',
#  'Reiten966 /',
#  'hashicorp /',
#  'pittcsc /',
#  'Technawi /',
#  'apache /',
#  'codeedu /',
#  'go-gorm /',
#  'elixir-ecto /',
#  'milvus-io /',
#  'knative /',
#  'Azure /',
#  'Alamofire /',
#  'OAI /',
#  'terraform-aws-modules /',
#  'google /',
#  'fastlane /',
#  'sourcegraph /',
#  'woocommerce /',
#  'firebase /']

# %%
desp_tags=driver.find_elements_by_xpath("//p[@class='col-9 color-fg-muted my-1 pr-4']")
desp_tags[0:24]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="ed695a47-8fae-4de5-a7fb-885d451acfe6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="3633740c-70f9-4514-a39f-d1bc797e278a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="6c0d2640-b5e6-43a6-a286-efe3c8e4f18f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="7b18b391-e961-4156-b028-ef39282e13bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="93335c08-634a-41e1-a07f-91cb447986b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="1c9ce773-a335-4a29-b87e-3a14dab8e85f")>,
# ...

# %%
for i in desp_tags:
    desp=i.text
    dep_descrp_list.append(desp)
dep_descrp_list[0:24]
# Out:
# ['🎨 Diagram as Code for prototyping cloud system architectures',
#  'Nomad is an easy-to-use, flexible, and performant workload orchestrator that can deploy a mix of microservice, batch, containerized, and non-containerized applications. Nomad is easy to operate and scale and has native Consul and Vault integrations.',
#  'Lexical is an extensible text editor framework that provides excellent reliability, accessibility and performance.',
#  'I am trying to describe complex matters in simple doodles!',
#  'A fully customizable iOS calendar library, compatible with Objective-C and Swift',
#  'The easiest way to automate your data',
#  'Polyformer is an open-source project that aims to recycle plastics into FDM filaments',
#  'HCL is the HashiCorp configuration language.',
#  'Collection of Summer 2023 tech internships!',
#  'Apache HBase',
#  'The fantastic ORM library for Golang, aims to be developer friendly',
#  'A toolkit for data mapping and language integrated query.',
# ...

# %%
cont_tags=driver.find_elements_by_xpath("//span[@class='d-inline-block mr-3']")
cont_tags[0:24]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="e0c2401c-383b-488c-88b5-70abe9867e4d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="a5ad8755-ed7d-4253-ba26-bd8e44ae441a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="72a5d513-c2ce-4945-8e86-3e8e6c2cff52")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="92025b00-08fd-4c9f-8294-f0b8d00663a3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="7a8b606e-dbbb-4d15-b474-631cc54b02e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="e5b38146-2e53-4b6f-b97b-70cdbb584fe7")>,
# ...

# %%
for i in cont_tags:
    cont=i.text
    cont_list.append(cont)
cont_list[0:24]
# Out:
# ['Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by']

# %%
lan_tags=driver.find_elements_by_xpath("//span[@class='d-inline-block ml-0 mr-3']")
lan_tags[0:24]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="ae5bcd35-c39f-4f0b-9b69-6d1cfc343495")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="40abbc26-5693-4e84-bc25-87f5b5d524ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="39f7aaf3-3643-4fd0-8487-c070d3382fff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="ac1c4a08-8c5b-438d-a758-46d6c1e36879")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="06c96dd3-af35-4a15-9702-d0e65bb4d332")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="feef4487f5683f9d289438406b94cf8b", element="e16941fe-b627-446d-ae49-28fb8ff5d05d")>,
# ...

# %%
for i in lan_tags:
    lan=i.text
    lan_list.append(lan)
lan_list[0:24]
# Out:
# ['Python',
#  'Go',
#  'TypeScript',
#  'Objective-C',
#  'Python',
#  'Go',
#  'Python',
#  'Java',
#  'TypeScript',
#  'Go',
#  'Elixir',
#  'Go',
#  'Go',
#  'Java',
#  'Swift',
#  'JavaScript',
#  'HCL',
#  'C++',
#  'Ruby',
#  'Go',
#  'PHP',
#  'Objective-C']

# %%
print(len(lan_list),len(cont_list),len(dep_descrp_list),len(dep_title_list))
# Out:
# 22 25 23 25

# %%
df=pd.DataFrame({})
df['Repository Tile']=dep_title_list[0:19]
df['Repository Description']=dep_descrp_list[0:19]
df['Contributors count']=cont_list[0:19]
df['Languages used']=lan_list[0:19]

# %%
df
# Out:
#    Repository Tile                             Repository Description  \
# 0     mingrammer /  🎨 Diagram as Code for prototyping cloud system...
# 1      hashicorp /  Nomad is an easy-to-use, flexible, and perform...
# 2       facebook /  Lexical is an extensible text editor framework...
# 3      girliemac /  I am trying to describe complex matters in sim...
# 4       WenchaoD /  A fully customizable iOS calendar library, com...
# 5      PrefectHQ /              The easiest way to automate your data
# 6      Reiten966 /  Polyformer is an open-source project that aims...
# 7      hashicorp /       HCL is the HashiCorp configuration language.
# 8        pittcsc /        Collection of Summer 2023 tech internships!
# 9       Technawi /                                       Apache HBase
# 10        apache /  The fantastic ORM library for Golang, aims to ...
# 11       codeedu /  A toolkit for data mapping and language integr...
# ...

# %%
driver.close()

# %% [markdown]
# # 6.  Scrape the details of top 100 songs on billiboard.com.

# %% [markdown]
# Importing required libraries

# %%
import pandas as pd
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https:/www.billboard.com/')

# %%
time.sleep(3)

# %%
hot_100=driver.find_element_by_xpath("//a[@class='c-link  lrv-a-unstyle-link lrv-u-color-brand-primary:hover lrv-a-hover-effect lrv-u-whitespace-nowrap lrv-u-color-grey-dark']")
hot_100.click()

# %%
song_list=[]
artist_list=[]
week_rank_list=[]
peak_list=[]
week_chart_list=[]

# %%
song_tags=driver.find_elements_by_xpath("//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only']")
song_tags[0:98]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="6739daad-b66e-4154-88e5-6438886e7112")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="e2a27af0-87f1-4f5c-9274-ef0e43f2b6bc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="af1ad8fb-8b7e-4565-ae4a-fd41457f2488")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="63bfcc07-450d-4a19-a7b5-1764749e922c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="54572e78-01d6-4d4d-91aa-c97b5a003972")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="3fcad2ec-15c2-4335-8397-d4ab8cdf03ee")>,
# ...

# %%
for i in song_tags:
    song=i.text
    song_list.append(song)
song_list[0:98]
# Out:
# ['First Class',
#  'Wait For U',
#  'About Damn Time',
#  'Running Up That Hill (A Deal With God)',
#  'Heat Waves',
#  'Big Energy',
#  'Me Porto Bonito',
#  'Titi Me Pregunto',
#  'Glimpse Of Us',
#  'Wasted On You',
#  'Stay',
#  'Yet To Come',
#  'I Like You (A Happier Song)',
#  'Late Night Talking',
#  'Boyfriend',
#  'Ghost',
#  'Enemy',
#  'Numb Little Bug',
#  'Bad Habits',
#  'Moscow Mule',
#  'Bam Bam',
#  'Woman',
#  'Rock And A Hard Place',
#  'Cold Heart (PNAU Remix)',
#  'Cash In Cash Out',
#  'Take My Name',
#  'Super Gremlin',
#  'Cooped Up',
#  'Thats What I Want',
#  'Shivers',
#  'Provenza',
#  'Get Into It (Yuh)',
#  'Sweetest Pie',
#  'AA',
#  'You Proof',
#  'Party',
#  'Despues de La Playa',
#  'Damn Strait',
#  'Efecto',
#  'Something In The Orange',
#  'Trouble With A Heartbreak',
#  'Ojitos Lindos',
#  'Thousand Miles',
#  "'Til You Can't",
#  'Fall In Love',
#  'Puffin On Zootiez',
#  'MAMIII',
#  'Like I Love Country Music',
#  'Hold My Hand',
# ...

# %%
artist_tags=driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
artist_tags[0:98]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="6a4fe501-0f6e-4bf3-b1be-17bbf2d95123")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="26604ee0-eb59-4180-93e5-52056ef901fe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="d70ae237-937a-470c-8fc7-f1e877164b15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="7acb8c23-13bd-480e-a5ce-43e4a2c61ef0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="c6b1b001-8cf5-4765-ac81-9d2e0c9dcfc6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="040bcdea-31db-49e1-8fb7-f3f041567cb3")>,
# ...

# %%
for i in artist_tags:
    artist=i.text
    artist_list.append(artist)
artist_list[0:98]
# Out:
# ['Jack Harlow',
#  'Future Featuring Drake & Tems',
#  'Lizzo',
#  'Kate Bush',
#  'Glass Animals',
#  'Latto',
#  'Bad Bunny & Chencho Corleone',
#  'Bad Bunny',
#  'Joji',
#  'Morgan Wallen',
#  'The Kid LAROI & Justin Bieber',
#  'BTS',
#  'Post Malone Featuring Doja Cat',
#  'Harry Styles',
#  'Dove Cameron',
#  'Justin Bieber',
#  'Imagine Dragons X JID',
#  'Em Beihold',
#  'Ed Sheeran',
#  'Bad Bunny',
#  'Camila Cabello Featuring Ed Sheeran',
#  'Doja Cat',
#  'Bailey Zimmerman',
#  'Elton John & Dua Lipa',
#  'Pharrell Williams Featuring 21 Savage & Tyler, The Creator',
#  'Parmalee',
#  'Kodak Black',
#  'Post Malone Featuring Roddy Ricch',
#  'Lil Nas X',
#  'Ed Sheeran',
#  'Karol G',
#  'Doja Cat',
#  'Megan Thee Stallion & Dua Lipa',
#  'Walker Hayes',
#  'Morgan Wallen',
#  'Bad Bunny & Rauw Alejandro',
#  'Bad Bunny',
#  'Scotty McCreery',
#  'Bad Bunny',
#  'Zach Bryan',
#  'Jason Aldean',
#  'Bad Bunny & Bomba Estereo',
#  'The Kid LAROI',
#  'Cody Johnson',
# ...

# %%
week_rank_tags=driver.find_elements_by_xpath("//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
week_rank_tags[0:98]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="71d95059-5b94-4991-87bf-a88810b81b84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="63d6eb67-c732-4645-b010-02fa5060fb86")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="59059a06-e048-4930-ba2e-1efbb69ba3ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="b9787472-3264-4cc5-a068-a74cd1535847")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="2d244313-3f74-47b6-b3bf-bdb6c40288ad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="4b0506b4-fb91-4e3d-9144-efa07c523716")>,
# ...

# %%
for i in week_rank_tags:
    week=i.text
    week_rank_list.append(week)
week_rank_list[0:98]
# Out:
# ['2',
#  '1',
#  '10',
#  '',
#  '',
#  '',
#  '3',
#  '1',
#  '7',
#  '',
#  '',
#  '',
#  '5',
#  '4',
#  '9',
#  '',
#  '',
#  '',
#  '4',
#  '4',
#  '23',
#  '',
#  '',
#  '',
#  '6',
#  '1',
#  '74',
#  '',
#  '',
#  '',
#  '7',
#  '3',
#  '34',
#  '',
#  '',
#  '',
#  '8',
#  '7',
#  '6',
#  '',
#  '',
#  '',
#  '10',
#  '5',
#  '6',
#  '',
#  '',
#  '',
#  '-',
#  '10',
#  '1',
#  '',
#  '',
#  '',
#  '13',
#  '9',
#  '31',
#  '',
#  '',
#  '',
#  '11',
#  '1',
#  '49',
#  '',
#  '',
#  '',
#  '-',
#  '13',
#  '1',
#  '',
#  '',
#  '',
#  '9',
#  '9',
#  '2',
#  '',
#  '',
#  '',
#  '15',
#  '4',
#  '4',
#  '',
#  '',
#  '',
#  '17',
#  '16',
#  '18',
#  '',
#  '',
#  '',
#  '16',
#  '5',
#  '38',
#  '',
#  '',
#  '',
#  '14',
#  '5']

# %%
peak_tags=driver.find_elements_by_xpath("//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
peak_tags[0:98]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="71d95059-5b94-4991-87bf-a88810b81b84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="63d6eb67-c732-4645-b010-02fa5060fb86")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="59059a06-e048-4930-ba2e-1efbb69ba3ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="b9787472-3264-4cc5-a068-a74cd1535847")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="2d244313-3f74-47b6-b3bf-bdb6c40288ad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="4b0506b4-fb91-4e3d-9144-efa07c523716")>,
# ...

# %%
for i in peak_tags:
    peak=i.text
    peak_list.append(peak)
peak_list[0:98]
# Out:
# ['2',
#  '1',
#  '10',
#  '',
#  '',
#  '',
#  '3',
#  '1',
#  '7',
#  '',
#  '',
#  '',
#  '5',
#  '4',
#  '9',
#  '',
#  '',
#  '',
#  '4',
#  '4',
#  '23',
#  '',
#  '',
#  '',
#  '6',
#  '1',
#  '74',
#  '',
#  '',
#  '',
#  '7',
#  '3',
#  '34',
#  '',
#  '',
#  '',
#  '8',
#  '7',
#  '6',
#  '',
#  '',
#  '',
#  '10',
#  '5',
#  '6',
#  '',
#  '',
#  '',
#  '-',
#  '10',
#  '1',
#  '',
#  '',
#  '',
#  '13',
#  '9',
#  '31',
#  '',
#  '',
#  '',
#  '11',
#  '1',
#  '49',
#  '',
#  '',
#  '',
#  '-',
#  '13',
#  '1',
#  '',
#  '',
#  '',
#  '9',
#  '9',
#  '2',
#  '',
#  '',
#  '',
#  '15',
#  '4',
#  '4',
#  '',
#  '',
#  '',
#  '17',
#  '16',
#  '18',
#  '',
#  '',
#  '',
#  '16',
#  '5',
#  '38',
#  '',
#  '',
#  '',
#  '14',
#  '5']

# %%
week_chart_tags=driver.find_elements_by_xpath("//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
week_chart_tags[0:98]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="71d95059-5b94-4991-87bf-a88810b81b84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="63d6eb67-c732-4645-b010-02fa5060fb86")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="59059a06-e048-4930-ba2e-1efbb69ba3ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="b9787472-3264-4cc5-a068-a74cd1535847")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="2d244313-3f74-47b6-b3bf-bdb6c40288ad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2ff98238004f8b7503f3cd5bffaf2f01", element="4b0506b4-fb91-4e3d-9144-efa07c523716")>,
# ...

# %%
for i in week_chart_tags:
    week=i.text
    week_chart_list.append(week)
week_chart_list[0:98]
# Out:
# ['2',
#  '1',
#  '10',
#  '',
#  '',
#  '',
#  '3',
#  '1',
#  '7',
#  '',
#  '',
#  '',
#  '5',
#  '4',
#  '9',
#  '',
#  '',
#  '',
#  '4',
#  '4',
#  '23',
#  '',
#  '',
#  '',
#  '6',
#  '1',
#  '74',
#  '',
#  '',
#  '',
#  '7',
#  '3',
#  '34',
#  '',
#  '',
#  '',
#  '8',
#  '7',
#  '6',
#  '',
#  '',
#  '',
#  '10',
#  '5',
#  '6',
#  '',
#  '',
#  '',
#  '-',
#  '10',
#  '1',
#  '',
#  '',
#  '',
#  '13',
#  '9',
#  '31',
#  '',
#  '',
#  '',
#  '11',
#  '1',
#  '49',
#  '',
#  '',
#  '',
#  '-',
#  '13',
#  '1',
#  '',
#  '',
#  '',
#  '9',
#  '9',
#  '2',
#  '',
#  '',
#  '',
#  '15',
#  '4',
#  '4',
#  '',
#  '',
#  '',
#  '17',
#  '16',
#  '18',
#  '',
#  '',
#  '',
#  '16',
#  '5',
#  '38',
#  '',
#  '',
#  '',
#  '14',
#  '5']

# %%
df=pd.DataFrame({})
df['Song name']=song_list[0:98]
df['Artist name']=artist_list[0:98]
df['Last week rank']=week_rank_list[0:98]
df['Peak rank']=peak_list[0:98]
df['Weeks on board']=week_chart_list[0:98]

# %%
df
# Out:
#                                  Song name  \
# 0                              First Class
# 1                               Wait For U
# 2                          About Damn Time
# 3   Running Up That Hill (A Deal With God)
# 4                               Heat Waves
# ..                                     ...
# 93                                Neverita
# 94                                  Plan B
# 95                             Tomorrow Me
# 96                                  Potion
# 97                               New Truck
#
#                              Artist name Last week rank Peak rank  \
# 0                            Jack Harlow              2         2
# 1          Future Featuring Drake & Tems              1         1
# 2                                  Lizzo             10        10
# 3                              Kate Bush
# 4                          Glass Animals
# ..                                   ...            ...       ...
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                                  Song name  \
# 0                              First Class
# 1                               Wait For U
# 2                          About Damn Time
# 3   Running Up That Hill (A Deal With God)
# 4                               Heat Waves
# 5                               Big Energy
# 6                          Me Porto Bonito
# 7                         Titi Me Pregunto
# 8                            Glimpse Of Us
# 9                            Wasted On You
# 10                                    Stay
# 11                             Yet To Come
# 12             I Like You (A Happier Song)
# 13                      Late Night Talking
# 14                               Boyfriend
# 15                                   Ghost
# 16                                   Enemy
# 17                         Numb Little Bug
# 18                              Bad Habits
# 19                             Moscow Mule
# 20                                 Bam Bam
# ...

# %%
driver.close()

# %% [markdown]
# # 9.  Scrape the details most watched tv series of all time from imdb.com.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
time.sleep(3)

# %%
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
time.sleep(3)

# %%
name_list=[]
year_list=[]
genre_list=[]
run_time_list=[]
ratings_list=[]
vote_list=[]

# %%
name_tags=driver.find_elements_by_xpath("//h3[@class='lister-item-header']")
name_tags[0:100]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="47d402b9-c9a3-4354-98c5-807a078120bf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="24087454-713b-4d00-9743-397126983fb1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="f3330ae7-440f-4b85-ad33-80845b79d96b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="54609e5f-8037-4926-a522-9570533a4c16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="562b2c77-4fa7-4e5e-a68d-1f497db39c33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="80e0dcb0-3fb5-43db-9ead-5abbbb6edd90")>,
# ...

# %%
for i in name_tags:
    name=i.text
    name_list.append(name)
name_list[0:100]
# Out:
# ['1. Game of Thrones (2011–2019)',
#  '2. Stranger Things (2016– )',
#  '3. The Walking Dead (2010–2022)',
#  '4. 13 Reasons Why (2017–2020)',
#  '5. The 100 (2014–2020)',
#  '6. Orange Is the New Black (2013–2019)',
#  '7. Riverdale (2017–2023)',
#  "8. Grey's Anatomy (2005– )",
#  '9. The Flash (2014– )',
#  '10. Arrow (2012–2020)',
#  '11. Money Heist (2017–2021)',
#  '12. The Big Bang Theory (2007–2019)',
#  '13. Black Mirror (2011– )',
#  '14. Sherlock (2010–2017)',
#  '15. Vikings (2013–2020)',
#  '16. Pretty Little Liars (2010–2017)',
#  '17. The Vampire Diaries (2009–2017)',
#  '18. American Horror Story (2011– )',
#  '19. Breaking Bad (2008–2013)',
#  '20. Lucifer (2016–2021)',
#  '21. Supernatural (2005–2020)',
#  '22. Prison Break (2005–2017)',
#  '23. How to Get Away with Murder (2014–2020)',
#  '24. Teen Wolf (2011–2017)',
#  '25. The Simpsons (1989– )',
#  '26. Once Upon a Time (2011–2018)',
#  '27. Narcos (2015–2017)',
#  '28. Daredevil (2015–2018)',
# ...

# %%
year_tags=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
year_tags[0:100]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="624fc9f0-8136-4028-b1a5-74c92dc575e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="f5207ef9-48de-4b1b-8e10-f9bc2dca056e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="d81d8e7b-ce72-49c1-98c1-8abab2beb0c5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="5bbfb50f-f7b1-4c09-919b-5ddae35b9531")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="7a003e67-c5b8-42e8-92ca-d4ba21ef8fbe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="9c7aa0b8-1c28-4bcb-a213-0d081143a9bf")>,
# ...

# %%
for i in year_tags:
    year=i.text
    year_list.append(year)
year_list[0:100]
# Out:
# ['(2011–2019)',
#  '(2016– )',
#  '(2010–2022)',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017–2023)',
#  '(2005– )',
#  '(2014– )',
#  '(2012–2020)',
#  '(2017–2021)',
#  '(2007–2019)',
#  '(2011– )',
#  '(2010–2017)',
#  '(2013–2020)',
#  '(2010–2017)',
#  '(2009–2017)',
#  '(2011– )',
#  '(2008–2013)',
#  '(2016–2021)',
#  '(2005–2020)',
#  '(2005–2017)',
#  '(2014–2020)',
#  '(2011–2017)',
#  '(1989– )',
#  '(2011–2018)',
#  '(2015–2017)',
#  '(2015–2018)',
#  '(1994–2004)',
#  '(2005–2014)',
#  '(2011–2019)',
#  '(2015–2019)',
#  '(2013–2018)',
#  '(2015–2021)',
#  '(2007–2012)',
#  '(2015–2018)',
#  '(2014–2019)',
#  '(2016– )',
#  '(2015–2019)',
#  '(2009–2020)',
#  '(2013– )',
#  '(2016–2019)',
#  '(2017–2019)',
#  '(2013–2018)',
#  '(2017–2020)',
#  '(2018– )',
#  '(2019– )',
#  '(2011–2021)',
#  '(2011–2018)',
#  '(2013–2020)',
#  '(2018– )',
#  '(2006–2013)',
#  '(2015– )',
#  '(1999– )',
#  '(2013– )',
#  '(2004–2010)',
#  '(2013–2022)',
# ...

# %%
genre_tags=driver.find_elements_by_xpath("//span[@class='genre']")
genre_tags[0:100]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="26df8f52-b5bd-44a7-ba81-9df8234be956")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="596096ce-f8cd-41b8-a70e-3c4fc4e36d0e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="adb60685-079f-4d9c-a0b5-efe6fb5a4d2a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="50d013c3-ddb1-4463-9eee-d39236dab727")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="b099c1fd-d9de-4f85-947b-122dfcbc8ae6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="06df33f1-46a6-4f27-b30f-f3f9adf6bc61")>,
# ...

# %%
for i in genre_tags:
    genre=i.text
    genre_list.append(genre)
genre_list[0:100]
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Drama, Mystery, Sci-Fi',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Sci-Fi',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
#  'Drama, Mystery, Sci-Fi',
# ...

# %%
run_time_tags=driver.find_elements_by_xpath("//span[@class='runtime']")
run_time_tags[0:100]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="cddd5587-5f05-41c6-8a6a-de82f8dcf3b1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="a6c5f54d-2328-40ff-ba60-870be076947b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="03af61f6-f5f7-4cb0-94d2-b3a02b46062c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="5aaec8de-bc0b-4638-88f8-16aa54b141aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="15bdc2cf-f125-4143-a852-9c55ecfea583")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="1a82f4c0-1360-4700-a412-38d7d2969fec")>,
# ...

# %%
for i in run_time_tags:
    run=i.text
    run_time_list.append(run)
run_time_list[0:100]
# Out:
# ['57 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '49 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '22 min',
#  '22 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '51 min',
#  '60 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '53 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '60 min',
#  '44 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
#  '45 min',
#  '46 min',
# ...

# %%
rating_tags=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']")
rating_tags[0:100]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="ca3ba236-c388-4078-9bf3-389fba1475a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="3f21ee17-cc31-45d6-af44-f2be6b1ef45c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="99d0ecaa-5058-4075-b816-897f70a4cfd9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="1b5386b5-bc1f-4cf1-a90c-4f00d1cb4aa9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="f2604be4-4f44-4502-9409-20a2f2f7b9cb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="2887126f-c060-4d28-8eb8-748c819c0fbc")>,
# ...

# %%
for i in rating_tags:
    rating=i.text
    ratings_list.append(rating)
ratings_list[0:100]
# Out:
# ['9.2',
#  '8.7',
#  '8.2',
#  '7.5',
#  '7.6',
#  '8.1',
#  '6.7',
#  '7.6',
#  '7.6',
#  '7.5',
#  '8.2',
#  '8.2',
#  '8.8',
#  '9.1',
#  '8.5',
#  '7.4',
#  '7.7',
#  '8',
#  '9.5',
#  '8.1',
#  '8.5',
#  '8.3',
#  '8.1',
#  '7.7',
#  '8.7',
#  '7.7',
#  '8.8',
#  '8.6',
#  '8.9',
#  '8.3',
#  '8.5',
#  '8.6',
#  '8.3',
#  '6.2',
#  '7.4',
#  '8.2',
#  '7.8',
#  '8.6',
#  '7.9',
#  '8.5',
#  '9.2',
#  '6.5',
#  '8.1',
#  '8.7',
#  '8.7',
#  '7.4',
#  '8.4',
#  '8.6',
#  '7.7',
#  '7.5',
#  '7.7',
#  '8.7',
#  '6.8',
#  '8.2',
#  '8',
#  '8.4',
#  '8.8',
#  '8.7',
#  '6.6',
#  '8.3',
#  '8.3',
#  '7.3',
#  '6.7',
#  '8.4',
#  '7.4',
#  '8.1',
#  '7.9',
#  '6.8',
#  '8.7',
#  '8.4',
#  '6.5',
#  '8',
#  '8.9',
#  '7.8',
#  '7.6',
#  '8.8',
#  '8.2',
#  '8.5',
#  '8.3',
#  '7.2',
#  '8.7',
#  '8.2',
#  '6.4',
#  '6.3',
#  '8.6',
#  '7.8',
#  '7.3',
#  '7.7',
#  '7.2',
#  '8.5',
#  '6.5',
#  '8.1',
#  '8.7',
#  '9.4',
#  '7.8',
#  '7.4',
#  '7.8',
#  '8.1',
#  '7.1',
#  '8.6']

# %%
vote_tags=driver.find_elements_by_xpath("//span[@name='nv']")
vote_tags[0:100]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="a3877d46-e9c2-4070-8f37-343dec375bdb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="35f54e31-4bd2-411a-938f-2fb5a55f8c11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="eb7dcf77-8648-47fa-a354-5269c93e97f3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="0982f918-37f2-4740-a685-c94572545ba3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="db636807-4fa0-4503-8cb7-3970d22789cf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b3d4fc92d956562ae30de0dfafc866e6", element="5cf5e8df-204e-4c03-911f-b8f861275a25")>,
# ...

# %%
for i in vote_tags:
    vote=i.text
    vote_list.append(vote)
vote_list[0:100]
# Out:
# ['1,998,514',
#  '1,046,795',
#  '951,009',
#  '284,234',
#  '244,018',
#  '296,900',
#  '140,099',
#  '296,619',
#  '338,948',
#  '426,820',
#  '458,717',
#  '786,364',
#  '521,556',
#  '897,594',
#  '512,473',
#  '163,964',
#  '312,629',
#  '308,257',
#  '1,751,865',
#  '310,512',
#  '431,341',
#  '519,986',
#  '147,736',
#  '143,797',
#  '397,116',
#  '221,198',
#  '407,706',
#  '423,073',
#  '957,527',
#  '665,924',
#  '398,334',
#  '376,214',
#  '132,544',
#  '122,473',
#  '170,601',
#  '152,265',
#  '227,039',
#  '479,387',
#  '210,137',
#  '413,062',
#  '480,132',
#  '61,627',
#  '180,126',
#  '496,040',
#  '359,013',
#  '74,357',
#  '263,776',
#  '231,855',
#  '217,738',
#  '214,463',
#  '228,018',
#  '713,990',
#  '127,816',
#  '329,460',
#  '241,061',
#  '539,039',
#  '498,264',
#  '450,850',
#  '60,472',
#  '109,267',
#  '336,270',
#  '72,771',
#  '103,260',
#  '218,386',
#  '91,210',
#  '90,184',
#  '48,369',
#  '146,307',
#  '361,512',
#  '297,405',
#  '105,703',
# ...

# %%
print(len(name_list),len(year_list),len(run_time_list),len(genre_list),len(ratings_list),len(vote_list))
# Out:
# 100 100 100 100 100 100

# %%
df=pd.DataFrame({})
df['Name']=name_list[0:99]
df['Year span']=year_list[0:99]
df['Genre']=genre_list[0:99]
df['Run time']=run_time_list[0:99]
df['Ratings']=ratings_list[0:99]
df['Votes']=vote_list[0:99]

# %%
df
# Out:
#                                               Name    Year span  \
# 0                   1. Game of Thrones (2011–2019)  (2011–2019)
# 1                      2. Stranger Things (2016– )     (2016– )
# 2                  3. The Walking Dead (2010–2022)  (2010–2022)
# 3                    4. 13 Reasons Why (2017–2020)  (2017–2020)
# 4                           5. The 100 (2014–2020)  (2014–2020)
# 5           6. Orange Is the New Black (2013–2019)  (2013–2019)
# 6                         7. Riverdale (2017–2023)  (2017–2023)
# 7                       8. Grey's Anatomy (2005– )     (2005– )
# 8                            9. The Flash (2014– )     (2014– )
# 9                            10. Arrow (2012–2020)  (2012–2020)
# 10                     11. Money Heist (2017–2021)  (2017–2021)
# 11             12. The Big Bang Theory (2007–2019)  (2007–2019)
# 12                       13. Black Mirror (2011– )     (2011– )
# 13                        14. Sherlock (2010–2017)  (2010–2017)
# ...

# %%
driver.close()

# %% [markdown]
# # 7.  Scrape the details of Data science recruiters from naukri.com.

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
time.sleep(3)

# %%
driver.get('https://www.naukri.com/')

# %%
time.sleep(3)

# %%
search_field_designation=driver.find_element_by_xpath("//input[@class='suggestor-input ']")
search_field_designation.send_keys("Data Science")

# %%
search_button=driver.find_element_by_xpath("//div[@class='qsbSubmit']")
search_button.click()

# %%
time.sleep(3)

# %%
rec_option=driver.find_element_by_xpath("/html/body/div[1]/div[1]/div/ul[1]/li[2]/a/div")
rec_option.click()

# %%
Nam_list=[]
desig_list=[]
comp_loc_list=[]
skill_list=[]

# %%
rec_name_tags=driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
rec_name_tags
# Out:
# []

# %%
for i in rec_name_tags:
    rec=i.text
    Nam_list.append(rec)
Nam_list[0:24]
# Out:
# []

# %%
desig_tags=driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
desig_tags[0:24]
# Out:
# []
